# %% [markdown]
# ---
# # Please replace all placeholder text in quotes before publishing. Remove the quotes too.
# title: "Full Title of Your Method"
# short_title: "Short Title <40 Characters"  # used when space is limited
# subtitle: "Optional subtitle providing more context"
# description: "Brief description of your method (1–2 sentences)."
#
# date: "YYYY-MM-DD"  # date of first publication
# updated: "YYYY-MM-DD"  # date of latest update
#
# license:
#   code: "license-ID"  # from https://spdx.org/licenses/
#   content: "license-ID"  # from https://spdx.org/licenses/
#
# github: "https://github.com/xxx"  # repository of this notebook
# doi: "https://doi.org/xxx"   # if you have one
# thumbnail: "./images/example.png"   # used on other pages to link to your notebook
#
# authors:
#   - name: "Full Name of Author"
#     orcid: "0000-0000-0000-0000"
#     corresponding: true  # for corresponding author, otherwise change to false
#     email: "author@example.com"
#     affiliations:
#       - name: "Organisation Name"
#         ror: "ror-ID"  # if it is a research organisation, from https://ror.org/
#
# funding:
#   - statement: "Funding statement."
#     awards:
#       - id: "award-id"
#         name: "Award name"
#         sources:
#           - name: "Funder Name"
# ---

# %% [markdown]
# # Full Title of Your Method

# %% [markdown]
# ## Challenge and Methodological Approach Summary
#
# Describe the challenge that your method addresses and the methodological approach that you use here.

# %% [markdown]
# ::::{tab-set}
# :::{tab-item} Running the Notebook
# :sync: tab1
# Describe the requirements for running your notebook. Explain hardware assumptions, key software dependencies and expected runtime.
# :::
# :::{tab-item} Data Access
# :sync: tab2
# Describe and provide links to the data you use in your notebook. Explain how data can be accessed and whether synthetic or sample data are provided.
# :::
# :::{tab-item} Assumptions
# :sync: tab3
# Explain the assumptions you make in your method.
# :::
# :::{tab-item} Generalisability
# :sync: tab4
# Describe the generalisability of your method. Explain where your method can be applied.
# :::
# :::{tab-item} Limitations
# :sync: tab5
# Describe the limitations of your method. Explain where your method should not be applied or may fail.
# :::
# ::::

# %% [markdown]
# The following provides an example of how to structure the rest of your notebook. Use headings, sub-headings, and a mix of code cells and markdown cells to guide others through your method step-by-step.

# %% [markdown]
# ## Importing Libraries and Loading Data

# %% [markdown]
# Describe the libraries that your method uses and why, and explain how you load data into your notebook.

# %%
# Importing libraries

# %%
# Loading data

# %%
# Displaying data

# %% [markdown]
# ## Method

# %% [markdown]
# Describe your method here.

# %% [markdown]
# ## Outputs and Interpretation

# %% [markdown]
# Display and describe the main outputs of your method and how they should be interpreted and used.
